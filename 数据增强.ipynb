# %%
import keras
from skimage import io,color,transform
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('D:/deeplearning/pic/xtf.jpg')  #244 x 207
plt.imshow(img)

# %%
# 通过
resized_image = cv2.resize(img, (1024, 1280))
plt.imshow(resized_image)
